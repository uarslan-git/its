# %%
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
from matplotlib.figure import Figure

class test_ax(Axes):
    def __init__(self, fig, *args, **kwargs):
        super(test_ax, self).__init__(fig, *args, **kwargs)

    #def scatter(self, x, y, *args, **kwargs):
    #    print("AAAAXE")
    #    return plt.scatter(x, y, *args, **kwargs)


fig = plt.figure()
ax = test_ax(fig, 111)
fig.add_axes(ax)
plt.subplots()
ax.scatter(0, 0)
ax.plot([1, 2], [3, 4])
fig.show()
# Out:
# /tmp/ipykernel_25666/2090574203.py:19: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
